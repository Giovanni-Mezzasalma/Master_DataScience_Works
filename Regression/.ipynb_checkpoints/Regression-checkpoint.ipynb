# %% [markdown]
# # Introduction to Data Science and Machine Learning
#
# <p align="center">
#     <img width="699" alt="image" src="https://user-images.githubusercontent.com/49638680/159042792-8510fbd1-c4ac-4a48-8320-bc6c1a49cdae.png">
# </p>
#
# ---
#
# ## Exercises
#
# ### Exercise - Regression
#
# Consider the [🍫 diabetes dataset](https://scikit-learn.org/stable/datasets/toy_dataset.html#diabetes-dataset) it contains data with $10$ features and a target value representing a quantitative measure of disease progression one year after baseline. Find the _best_ polynomial fit based on the test score for this dataset.
#
# Perform exploratory data analysis, define a suitable performance metric and justify _all_ your choices.
# Plot histograms of features distributions and correlation diagrams.

# %%
import pandas as pd
import numpy as np

from sklearn.datasets import load_diabetes

from sklearn.linear_model import LinearRegression
from sklearn.preprocessing import PolynomialFeatures
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error
from sklearn.model_selection import GridSearchCV

import matplotlib.pyplot as plt
import seaborn as sns

plt.rcParams.update({'font.size': 20, 'figure.figsize': (20, 13)})

# %%
dt = load_diabetes()
dt
# Out:
# {'data': array([[ 0.03807591,  0.05068012,  0.06169621, ..., -0.00259226,
#           0.01990842, -0.01764613],
#         [-0.00188202, -0.04464164, -0.05147406, ..., -0.03949338,
#          -0.06832974, -0.09220405],
#         [ 0.08529891,  0.05068012,  0.04445121, ..., -0.00259226,
#           0.00286377, -0.02593034],
#         ...,
#         [ 0.04170844,  0.05068012, -0.01590626, ..., -0.01107952,
#          -0.04687948,  0.01549073],
#         [-0.04547248, -0.04464164,  0.03906215, ...,  0.02655962,
#           0.04452837, -0.02593034],
#         [-0.04547248, -0.04464164, -0.0730303 , ..., -0.03949338,
#          -0.00421986,  0.00306441]]),
#  'target': array([151.,  75., 141., 206., 135.,  97., 138.,  63., 110., 310., 101.,
#          69., 179., 185., 118., 171., 166., 144.,  97., 168.,  68.,  49.,
#          68., 245., 184., 202., 137.,  85., 131., 283., 129.,  59., 341.,
#          87.,  65., 102., 265., 276., 252.,  90., 100.,  55.,  61.,  92.,
# ...

# %%
data = pd.DataFrame(dt['data'], columns = dt['feature_names'])
data['target'] = dt['target']
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 442 entries, 0 to 441
# Data columns (total 11 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   age     442 non-null    float64
#  1   sex     442 non-null    float64
#  2   bmi     442 non-null    float64
#  3   bp      442 non-null    float64
#  4   s1      442 non-null    float64
#  5   s2      442 non-null    float64
#  6   s3      442 non-null    float64
#  7   s4      442 non-null    float64
#  8   s5      442 non-null    float64
#  9   s6      442 non-null    float64
#  10  target  442 non-null    float64
# dtypes: float64(11)
# memory usage: 38.1 KB

# %%
X=data[data.columns[0:-1]]
y=data[data.columns[-1]]

#split train and test sets
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.1, random_state=42)

df_train=pd.DataFrame(X_train, columns = data.columns[0:-1])
df_train['target']=y_train

df_test=pd.DataFrame(X_test, columns = data.columns[0:-1])
df_test['target']=y_test

# %%
g = sns.PairGrid(df_train, height=4)
g.map_upper(sns.scatterplot)
g.map_lower(sns.kdeplot, fill=True)
g.map_diag(sns.histplot, kde=True);

# %%
sns.heatmap(df_train.corr(), annot = True, cmap = 'coolwarm')
# Out:
# <AxesSubplot:>

# %% [markdown]
# Dai plot si nota come si ha una buona correlazione con le varie feature, quasi tutte sopra 0.3 tranne per 'age', 'sex', 's1' e 's2'.
# Questo mi fa capire come un polinomio di grado uno potrebbe essere sufficiente per l'algoritmo di regressione lineare.

# %%
fig,axes = plt.subplots(4, 3, constrained_layout = True,figsize = (20,10))
for i,ax in enumerate(axes.ravel()):
    if i > 10:
        fig.delaxes(ax)
        continue
    rgb = np.random.rand(3,)
    sns.histplot( x = df_train.iloc[:,i], kde = True, color = rgb, ax = ax)

# %% [markdown]
# Visualizzo la distribuzione dei dati per avere un'idea sulla loro distribuzione

# %%
corr = df_train.corr().target
corr
# Out:
# age       0.188185
# sex       0.021537
# bmi       0.583508
# bp        0.440617
# s1        0.211095
# s2        0.171855
# s3       -0.388870
# s4        0.423206
# s5        0.556827
# s6        0.384982
# target    1.000000
# Name: target, dtype: float64

# %%
fig, axes = plt.subplots(4,3, constrained_layout = True, figsize=(20,20))
for i, ax in enumerate(axes.ravel()):
    if i >9:
        fig.delaxes(ax)
        continue
    rgb = np.random.rand(3,)
    sns.regplot(x = df_train[corr.index[i]], y = df_train[corr.index[10]], line_kws={'linewidth':5},color = rgb, ax = ax)

# %% [markdown]
# Visualizzo le correlazioni e plotto i grafici

# %%
k=[i for i in range(1,5)]
scores=[]
degree=[]
rel_err=[]
mean_sqrt=[]
ass_err=[]
for i in k:
    poly = PolynomialFeatures(degree = i, include_bias = False)
    X_train_ = poly.fit_transform(X_train)
    X_test_ = poly.fit_transform(X_test)
    model = LinearRegression()
    model.fit(X_train_, y_train)
    y_pred=model.predict(X_test_)
    rel=np.mean(abs((y_pred-y_test)/y_test))
    ass=np.mean(abs((y_pred-y_test)))
    mean=np.sqrt(mean_squared_error(y_pred, y_test))
    scores.append(model.score(X_test_, y_test))
    rel_err.append(rel)
    mean_sqrt.append(mean)
    ass_err.append(ass)
    degree.append(i)
    
print(f"\nConsiderando un polinomio di grado {degree[np.argmax(scores)]}\nsi ottiene un accuratezza pari a {np.round(max(scores),3)*100}%" )

print(f"\nPer ottenere l'errore minimo, pari a {np.round(min(rel_err),2)*100}%,\n(calcolato come media degli errori relativi)\nbisogna utilizzare un polinomio di grado {degree[np.argmin(rel_err)]}" )

print(f"\nPer ottenere l'errore minimo, pari a {np.round(min(mean_sqrt),2)},\n(calcolato usando l'errore quadratico medio)\nbisogna utilizzare un polinomio di grado {degree[np.argmin(mean_sqrt)]}" )

print(f"\nPer ottenere l'errore minimo, pari a {np.round(min(ass_err),2)},\n(calcolato usando l'errore assoluto medio)\nbisogna utilizzare un polinomio di grado {degree[np.argmin(ass_err)]}" )
# Out:
# Considerando un polinomio di grado 1
# si ottiene un accuratezza pari a 55.1%
#
# Per ottenere l'errore minimo, pari a 33.0%,
# (calcolato come media degli errori relativi)
# bisogna utilizzare un polinomio di grado 2
#
# Per ottenere l'errore minimo, pari a 52.38,
# (calcolato usando l'errore quadratico medio)
# bisogna utilizzare un polinomio di grado 1
#
# Per ottenere l'errore minimo, pari a 41.58,
# (calcolato usando l'errore assoluto medio)
# bisogna utilizzare un polinomio di grado 1

# %% [markdown]
# Dai grafici già si notava una correlazione lineare, ma ho testato per essere certo che un polinomio di primo grado fosse la scelta giusta per l'algoritmo di regressione lineare.

# %%
poly = PolynomialFeatures(degree = 1, include_bias = False)
X_train_ = poly.fit_transform(X_train)
X_test_ = poly.fit_transform(X_test)
model = LinearRegression()
model.fit(X_train_, y_train)
y_pred=model.predict(X_test_)
err_rel_lr=abs((y_pred-y_test)/y_test)

# %%
from sklearn.neighbors import KNeighborsRegressor

# %%
k=[i for i in range(2,30) if i%2!=0]
dist=['euclidean','cosine','manhattan']

# %%
best_scores=[]
best_rel_err=[]
best_mean_sqrt=[]
best_k=[]
best_ass_err=[]
for j in dist:
    scores=[]
    rel_err=[]
    mean_sqrt=[]
    ass_err=[]
    for i in k:
        knn = KNeighborsRegressor(n_neighbors=i, metric=j)
        knn.fit(X_train,y_train)
        scores.append(knn.score(X_test, y_test))
        y_pred=knn.predict(X_test)
        rel=np.mean(abs((y_pred-y_test)/y_test))
        mean=np.sqrt(mean_squared_error(y_pred, y_test))
        ass=np.mean(abs((y_pred-y_test)))
        rel_err.append(rel)
        mean_sqrt.append(mean)
        ass_err.append(ass)
    
    best_scores.append(np.max(scores))
    best_rel_err.append(np.min(rel_err))
    best_ass_err.append(np.min(ass_err))
    best_mean_sqrt.append(np.min(mean_sqrt))
    best_k.append(k[np.argmax(scores)])
    plt.plot(k,scores,label=j)
    
plt.xlabel('N° of neighbors')  # Add an x-label to the axes.
plt.ylabel('Accuracy')  # Add a y-label to the axes.
plt.title("Accuracy trend")
plt.legend()

print(f"La scelta migliore risulta utilizzando la distanza {dist[np.argmax(best_scores)]},\ncon un k={best_k[np.argmax(best_scores)]} e un'accuratezza pari a {np.round(np.max(best_scores)*100,2)}%")
print(f"\nL'errore relativo è pari a {np.round(min(best_rel_err),2)*100}%\ne l'errore quadradico medio è pari a {np.round(min(best_mean_sqrt),2)},\nL'errore assoluto è pari a {np.round(min(best_ass_err),2)}")
# Out:
# La scelta migliore risulta utilizzando la distanza cosine,
# con un k=13 e un'accuratezza pari a 61.35%
#
# L'errore relativo è pari a 33.0%
# e l'errore quadradico medio è pari a 48.62,
# L'errore assoluto è pari a 39.11

# %% [markdown]
# Per confronto ho utilizzato anche l'algoritmo knn, per verificare se l'accuratezza del modello cambia.
# Effettivamente sembra che il modello knn sia più accurato, di circa il 6% in più, rispetto al modello di regressione lineare.
# L'errore quadradico medio è inferiore per il knn rispetto al modello di regressione lineare.
# Mentre l'errore relativo medio non sembra variare molto.

# %%
knn = KNeighborsRegressor(n_neighbors=13, metric='cosine')
knn.fit(X_train,y_train)
y_pred=knn.predict(X_test)
err_rel_knn=abs((y_pred-y_test)/y_test)

# %%
parameters = {'n_neighbors':[i for i in range(1,30) if i%2!=0],
              'weights':['uniform', 'distance'],
              'metric':['euclidean','manhattan', 'cosine']}
knn = KNeighborsRegressor()
grid = GridSearchCV(knn, parameters) 
grid.fit(X_train, y_train)
print('KNN score =', grid.best_estimator_.score(X_test, y_test))
print('KNN best parameters =', grid.best_params_)

hmknn = pd.pivot_table(pd.DataFrame(grid.cv_results_),
									values='mean_test_score',
									index='param_n_neighbors',
									columns='param_metric')

sns.heatmap(hmknn, cmap = 'magma', annot = True)

#Calcolo gli scarti dei dati dal modello
err_knn = (grid.predict(X_test) - y_test)/y_test
# Out:
# KNN score = 0.5616401122324619
# KNN best parameters = {'metric': 'cosine', 'n_neighbors': 25, 'weights': 'distance'}

# %% [markdown]
# Ho utilizzato la gridsearch per verificare quali siano i parametri migliori da utilizzare per il modello knn ,il risultato è che con il codice precedente ho ottenuto del parametri differenti e sopratutto un'accuratezza maggiore rispetto alla ricerca dei parametri tramite la gridsearch.

# %% [markdown]
# Per provare a migliorare la previsione ho provato a modificare i dati. Infatti ho moltiplicato ciascuna colonna per la corrispondete correlazione con la colonna target, successivamente ho sommato tutti i prodotti e ho ottenuto una nuova colonna.
# Quindi ho utilizzato di nuovo i modelli utilizzati in precedenza per verificare se questo porta a un miglioramento o meno.

# %%
corr=data.corr().target[:-1]
data_corr=X*corr
data.drop('target', axis = 1, inplace = True)
data['sum']=data_corr.age+data_corr.sex+data_corr.bmi+data_corr.bp+data_corr.s1+data_corr.s2+data_corr.s3+data_corr.s4+data_corr.s5+data_corr.s6
data['target']=y

# %%
X=data[data.columns[0:-1]]
y=data[data.columns[-1]]

#split train and test sets
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.1, random_state=42)

df_train=pd.DataFrame(X_train, columns = data.columns[0:-1])
df_train['target']=y_train

df_test=pd.DataFrame(X_test, columns = data.columns[0:-1])
df_test['target']=y_test

# %%
k=[i for i in range(1,5)]
scores=[]
degree=[]
rel_err=[]
mean_sqrt=[]
ass_err=[]
for i in k:
    poly = PolynomialFeatures(degree = i, include_bias = False)
    X_train_ = poly.fit_transform(X_train)
    X_test_ = poly.fit_transform(X_test)
    model = LinearRegression()
    model.fit(X_train_, y_train)
    y_pred=model.predict(X_test_)
    rel=np.mean(abs((y_pred-y_test)/y_test))
    ass=np.mean(abs((y_pred-y_test)))
    mean=np.sqrt(mean_squared_error(y_pred, y_test))
    scores.append(model.score(X_test_, y_test))
    rel_err.append(rel)
    mean_sqrt.append(mean)
    ass_err.append(ass)
    degree.append(i)
    
print(f"\nConsiderando un polinomio di grado {degree[np.argmax(scores)]}\nsi ottiene un accuratezza pari a {np.round(max(scores),3)*100}%" )

print(f"\nPer ottenere l'errore minimo, pari a {np.round(min(rel_err),2)*100}%,\n(calcolato come media degli errori relativi)\nbisogna utilizzare un polinomio di grado {degree[np.argmin(rel_err)]}" )

print(f"\nPer ottenere l'errore minimo, pari a {np.round(min(mean_sqrt),2)},\n(calcolato usando l'errore quadratico medio)\nbisogna utilizzare un polinomio di grado {degree[np.argmin(mean_sqrt)]}" )

print(f"\nPer ottenere l'errore minimo, pari a {np.round(min(ass_err),2)},\n(calcolato usando l'errore assoluto medio)\nbisogna utilizzare un polinomio di grado {degree[np.argmin(ass_err)]}" )
# Out:
# Considerando un polinomio di grado 1
# si ottiene un accuratezza pari a 55.1%
#
# Per ottenere l'errore minimo, pari a 33.0%,
# (calcolato come media degli errori relativi)
# bisogna utilizzare un polinomio di grado 2
#
# Per ottenere l'errore minimo, pari a 52.38,
# (calcolato usando l'errore quadratico medio)
# bisogna utilizzare un polinomio di grado 1
#
# Per ottenere l'errore minimo, pari a 41.58,
# (calcolato usando l'errore assoluto medio)
# bisogna utilizzare un polinomio di grado 1

# %% [markdown]
# Con il modello di regressione lineare non sembra ci siano miglioramenti, nè peggioramenti, anzi i risultati sembrano invariati!

# %%
poly = PolynomialFeatures(degree = 1, include_bias = False)
X_train_ = poly.fit_transform(X_train)
X_test_ = poly.fit_transform(X_test)
model = LinearRegression()
model.fit(X_train_, y_train)
y_pred=model.predict(X_test_)
err_rel_lr_corr=abs((y_pred-y_test)/y_test)

# %%
k=[i for i in range(2,30) if i%2!=0]
dist=['euclidean','cosine','manhattan']

# %%
best_scores=[]
best_rel_err=[]
best_mean_sqrt=[]
best_k=[]
best_ass_err=[]
for j in dist:
    scores=[]
    rel_err=[]
    mean_sqrt=[]
    ass_err=[]
    for i in k:
        knn = KNeighborsRegressor(n_neighbors=i, metric=j)
        knn.fit(X_train,y_train)
        scores.append(knn.score(X_test, y_test))
        y_pred=knn.predict(X_test)
        rel=np.mean(abs((y_pred-y_test)/y_test))
        mean=np.sqrt(mean_squared_error(y_pred, y_test))
        ass=np.mean(abs((y_pred-y_test)))
        rel_err.append(rel)
        mean_sqrt.append(mean)
        ass_err.append(ass)
    
    best_scores.append(np.max(scores))
    best_rel_err.append(np.min(rel_err))
    best_ass_err.append(np.min(ass_err))
    best_mean_sqrt.append(np.min(mean_sqrt))
    best_k.append(k[np.argmax(scores)])
    plt.plot(k,scores,label=j)
    
plt.xlabel('N° of neighbors')  # Add an x-label to the axes.
plt.ylabel('Accuracy')  # Add a y-label to the axes.
plt.title("Accuracy trend")
plt.legend()

print(f"La scelta migliore risulta utilizzando la distanza {dist[np.argmax(best_scores)]},\ncon un k={best_k[np.argmax(best_scores)]} e un'accuratezza pari a {np.round(np.max(best_scores)*100,2)}%")
print(f"\nL'errore relativo è pari a {np.round(min(best_rel_err),2)*100}%\ne l'errore quadradico medio è pari a {np.round(min(best_mean_sqrt),2)},\nL'errore assoluto è pari a {np.round(min(best_ass_err),2)}")
# Out:
# La scelta migliore risulta utilizzando la distanza cosine,
# con un k=9 e un'accuratezza pari a 64.04%
#
# L'errore relativo è pari a 32.0%
# e l'errore quadradico medio è pari a 46.9,
# L'errore assoluto è pari a 36.48

# %% [markdown]
# Il modello knn sembra mostrare un leggero miglioramento rispetto al precedente, infatti l'accuratezza è aumentato anche se di poco, mentre gli errori risultano essere inferiori.

# %%
knn = KNeighborsRegressor(n_neighbors=9, metric='cosine')
knn.fit(X_train,y_train)
y_pred=knn.predict(X_test)
err_rel_knn_corr=abs((y_pred-y_test)/y_test)

# %%
parameters = {'n_neighbors':[i for i in range(1,30) if i%2!=0],
              'weights':['uniform', 'distance'],
              'metric':['euclidean','manhattan', 'cosine']}
knn = KNeighborsRegressor()
grid = GridSearchCV(knn, parameters) 
grid.fit(X_train, y_train)
print('KNN score =', grid.best_estimator_.score(X_test, y_test))
print('KNN best parameters =', grid.best_params_)

hmknn = pd.pivot_table(pd.DataFrame(grid.cv_results_),
									values='mean_test_score',
									index='param_n_neighbors',
									columns='param_metric')

sns.heatmap(hmknn, cmap = 'magma', annot = True)

#Calcolo gli scarti dei dati dal modello
err_knn_corr = (grid.predict(X_test) - y_test)/y_test
# Out:
# KNN score = 0.5585575977637011
# KNN best parameters = {'metric': 'euclidean', 'n_neighbors': 17, 'weights': 'distance'}

# %% [markdown]
# Anche in questo caso sembra ci sia una discrepanza, come in precedenza. Inoltre in questo caso, l'accuratezza risulta inferiore rispetto a quella calcolata in precedenza, anche se di poco.

# %%
c = np.random.uniform(0,0.5,3)

sns.histplot(err_rel_lr, alpha = 0.6, label = 'linear regression', kde = True, color = np.random.rand(3,) )
sns.histplot(err_rel_lr_corr, alpha = 0.4, label = 'linear regression with new column', kde = True, color = np.random.rand(3,))

plt.legend()
plt.title('Distribuzione errori relativi')
# Out:
# Text(0.5, 1.0, 'Distribuzione errori relativi')

# %% [markdown]
# Come visto in precedenza, l'aggiunta della nuova colonna non apporta nessun tipo di cambiamento, infatti i due grafici si sovrappongono.

# %%
c = np.random.uniform(0,0.5,3)

sns.histplot(err_rel_knn, alpha = 0.4, label = 'knn', kde = True, color = np.random.rand(3,))
sns.histplot(err_rel_knn_corr, alpha = 0.4, label = 'knn with new column', kde = True, color = np.random.rand(3,))

plt.legend()
plt.title('Distribuzione errori relativi')
# Out:
# Text(0.5, 1.0, 'Distribuzione errori relativi')

# %% [markdown]
# Dal grafico si nota come l'aggiunta della nuova colonna porta ad un leggero peggioramento

# %%
c = np.random.uniform(0,0.5,3)

sns.histplot(err_knn, alpha = 0.4, label = 'knn grid search', kde = True, color = np.random.rand(3,))
sns.histplot(err_knn_corr, alpha = 0.4, label = 'knn grid search with new column', kde = True, color = np.random.rand(3,))

plt.legend()
plt.title('Distribuzione errori relativi')
# Out:
# Text(0.5, 1.0, 'Distribuzione errori relativi')

# %% [markdown]
# Anche in questo caso l'aggiunta della nuova colonna porta ad un leggero peggioramento

# %%
c = np.random.uniform(0,0.5,3)

sns.histplot(err_rel_lr, alpha = 0.4, label = 'linear regression', kde = True, color = np.random.rand(3,) )
sns.histplot(err_rel_lr_corr, alpha = 0.4, label = 'linear regression with new column', kde = True, color = np.random.rand(3,))
sns.histplot(err_rel_knn, alpha = 0.4, label = 'knn', kde = True, color = np.random.rand(3,))
sns.histplot(err_rel_knn_corr, alpha = 0.4, label = 'knn with new column', kde = True, color = np.random.rand(3,))
sns.histplot(err_knn, alpha = 0.4, label = 'knn grid search', kde = True, color = np.random.rand(3,))
sns.histplot(err_knn_corr, alpha = 0.4, label = 'knn grid search with new column', kde = True, color = np.random.rand(3,))

plt.legend()
plt.title('Distribuzione errori relativi')
# Out:
# Text(0.5, 1.0, 'Distribuzione errori relativi')

# %% [markdown]
# In conclusione il modello knn risulta essere il più preciso per la previsione, l'aggiunta della colonna non sembra migliorare in maniera significativa i modelli.

# %%
data = pd.DataFrame(dt['data'], columns = dt['feature_names'])
data['target'] = dt['target']

# %%
data.drop('s2', axis = 1, inplace = True)
data.drop('s4', axis = 1, inplace = True)

# %%
X=data[data.columns[0:-1]]
y=data[data.columns[-1]]

#split train and test sets
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.1, random_state=42)

df_train=pd.DataFrame(X_train, columns = data.columns[0:-1])
df_train['target']=y_train

df_test=pd.DataFrame(X_test, columns = data.columns[0:-1])
df_test['target']=y_test

# %%
sns.heatmap(df_train.corr(), annot = True, cmap = 'coolwarm')
# Out:
# <AxesSubplot:>

# %%
k=[i for i in range(1,5)]
scores=[]
degree=[]
rel_err=[]
mean_sqrt=[]
ass_err=[]
for i in k:
    poly = PolynomialFeatures(degree = i, include_bias = False)
    X_train_ = poly.fit_transform(X_train)
    X_test_ = poly.fit_transform(X_test)
    model = LinearRegression()
    model.fit(X_train_, y_train)
    y_pred=model.predict(X_test_)
    rel=np.mean(abs((y_pred-y_test)/y_test))
    ass=np.mean(abs((y_pred-y_test)))
    mean=np.sqrt(mean_squared_error(y_pred, y_test))
    scores.append(model.score(X_test_, y_test))
    rel_err.append(rel)
    mean_sqrt.append(mean)
    ass_err.append(ass)
    degree.append(i)
    
print(f"\nConsiderando un polinomio di grado {degree[np.argmax(scores)]}\nsi ottiene un accuratezza pari a {np.round(max(scores),3)*100}%" )

print(f"\nPer ottenere l'errore minimo, pari a {np.round(min(rel_err),2)*100}%,\n(calcolato come media degli errori relativi)\nbisogna utilizzare un polinomio di grado {degree[np.argmin(rel_err)]}" )

print(f"\nPer ottenere l'errore minimo, pari a {np.round(min(mean_sqrt),2)},\n(calcolato usando l'errore quadratico medio)\nbisogna utilizzare un polinomio di grado {degree[np.argmin(mean_sqrt)]}" )

print(f"\nPer ottenere l'errore minimo, pari a {np.round(min(ass_err),2)},\n(calcolato usando l'errore assoluto medio)\nbisogna utilizzare un polinomio di grado {degree[np.argmin(ass_err)]}" )
# Out:
# Considerando un polinomio di grado 2
# si ottiene un accuratezza pari a 58.3%
#
# Per ottenere l'errore minimo, pari a 31.0%,
# (calcolato come media degli errori relativi)
# bisogna utilizzare un polinomio di grado 2
#
# Per ottenere l'errore minimo, pari a 50.51,
# (calcolato usando l'errore quadratico medio)
# bisogna utilizzare un polinomio di grado 2
#
# Per ottenere l'errore minimo, pari a 38.43,
# (calcolato usando l'errore assoluto medio)
# bisogna utilizzare un polinomio di grado 2

# %%
k=[i for i in range(2,30) if i%2!=0]
dist=['euclidean','cosine','manhattan']

# %%
best_scores=[]
best_rel_err=[]
best_mean_sqrt=[]
best_k=[]
best_ass_err=[]
for j in dist:
    scores=[]
    rel_err=[]
    mean_sqrt=[]
    ass_err=[]
    for i in k:
        knn = KNeighborsRegressor(n_neighbors=i, metric=j)
        knn.fit(X_train,y_train)
        scores.append(knn.score(X_test, y_test))
        y_pred=knn.predict(X_test)
        rel=np.mean(abs((y_pred-y_test)/y_test))
        mean=np.sqrt(mean_squared_error(y_pred, y_test))
        ass=np.mean(abs((y_pred-y_test)))
        rel_err.append(rel)
        mean_sqrt.append(mean)
        ass_err.append(ass)
    
    best_scores.append(np.max(scores))
    best_rel_err.append(np.min(rel_err))
    best_ass_err.append(np.min(ass_err))
    best_mean_sqrt.append(np.min(mean_sqrt))
    best_k.append(k[np.argmax(scores)])
    plt.plot(k,scores,label=j)
    
plt.xlabel('N° of neighbors')  # Add an x-label to the axes.
plt.ylabel('Accuracy')  # Add a y-label to the axes.
plt.title("Accuracy trend")
plt.legend()

print(f"La scelta migliore risulta utilizzando la distanza {dist[np.argmax(best_scores)]},\ncon un k={best_k[np.argmax(best_scores)]} e un'accuratezza pari a {np.round(np.max(best_scores)*100,2)}%")
print(f"\nL'errore relativo è pari a {np.round(min(best_rel_err),2)*100}%\ne l'errore quadradico medio è pari a {np.round(min(best_mean_sqrt),2)},\nL'errore assoluto è pari a {np.round(min(best_ass_err),2)}")
# Out:
# La scelta migliore risulta utilizzando la distanza cosine,
# con un k=9 e un'accuratezza pari a 68.31%
#
# L'errore relativo è pari a 32.0%
# e l'errore quadradico medio è pari a 44.03,
# L'errore assoluto è pari a 34.46
