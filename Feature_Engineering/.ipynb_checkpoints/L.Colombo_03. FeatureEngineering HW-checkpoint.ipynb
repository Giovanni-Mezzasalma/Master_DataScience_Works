# %% [markdown]
# # Introduction to Data Science and Machine Learning
#
# <p align="center">
#     <img width="699" alt="image" src="https://user-images.githubusercontent.com/49638680/159042792-8510fbd1-c4ac-4a48-8320-bc6c1a49cdae.png">
# </p>
#
# ---
#
# ## Feature Engineering Homework
#
# Perform feature engineering on a dataset to transform data into a suitable form for a machine learning algorithm.
#
# __Bonus__: Make nice (and _useful_) data visualisation plots.
#
# ### The dataset
#
# The [Concrete](https://www.kaggle.com/sinamhd9/concrete-comprehensive-strength) dataset contains a variety of concrete formulations and the resulting product's compressive strength, which is a measure of how much load that kind of concrete can bear. For your information, the task for this dataset is to predict a concrete's compressive strength given its formulation.

# %%
# Import libraries
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt
import seaborn as sns

# %matplotlib inline
# %config InlineBackend.figure_format = "retina"

# set font and plot size to be larger
plt.rcParams.update({'font.size': 20, 'figure.figsize': (20, 13)})

# %% [markdown]
# ### Import data

# %%
url_data = "https://raw.githubusercontent.com/stedy/Machine-Learning-with-R-datasets/master/concrete.csv"

df = pd.read_csv(url_data)
df.head()
# Out:
#    cement   slag  ash  water  superplastic  coarseagg  fineagg  age  strength
# 0   540.0    0.0  0.0  162.0           2.5     1040.0    676.0   28     79.99
# 1   540.0    0.0  0.0  162.0           2.5     1055.0    676.0   28     61.89
# 2   332.5  142.5  0.0  228.0           0.0      932.0    594.0  270     40.27
# 3   332.5  142.5  0.0  228.0           0.0      932.0    594.0  365     41.05
# 4   198.6  132.4  0.0  192.0           0.0      978.4    825.5  360     44.30

# %% [markdown]
# <details>
#     <summary><b>Hints and suggestions</b></summary>
#     You can see here the various ingredients going into each variety of concrete.
#     Here some suggestions that you might find useful.
#     <ul>
#         <li> Adding some additional synthetic features derived from the original ones in the dataset can help a model to learn important relationships among them.</li>
#         <li> Try to establish a <b>baseline</b> (_e.g._ a simple stupid model) by training the model on the untouched dataset. This will help you determine whether our new features are actually useful.</li>
#     </ul>
#     Establishing baselines like this is good practice at the start of the feature engineering process. A baseline score can help you decide whether your new features are worth keeping, or whether you should discard them and possibly try something else.
# </details>
#
#
# ---
#
# ## Your work

# %%
#controllo che tipo di dati ho

df.info(memory_usage='deep') #100% valori non nulli, tutti floea tranne age che è un int
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1030 entries, 0 to 1029
# Data columns (total 9 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   cement        1030 non-null   float64
#  1   slag          1030 non-null   float64
#  2   ash           1030 non-null   float64
#  3   water         1030 non-null   float64
#  4   superplastic  1030 non-null   float64
#  5   coarseagg     1030 non-null   float64
#  6   fineagg       1030 non-null   float64
#  7   age           1030 non-null   int64
#  8   strength      1030 non-null   float64
# dtypes: float64(8), int64(1)
# memory usage: 72.5 KB

# %%
df.describe()
# Out:
#             cement         slag          ash        water  superplastic  \
# count  1030.000000  1030.000000  1030.000000  1030.000000   1030.000000
# mean    281.167864    73.895825    54.188350   181.567282      6.204660
# std     104.506364    86.279342    63.997004    21.354219      5.973841
# min     102.000000     0.000000     0.000000   121.800000      0.000000
# 25%     192.375000     0.000000     0.000000   164.900000      0.000000
# 50%     272.900000    22.000000     0.000000   185.000000      6.400000
# 75%     350.000000   142.950000   118.300000   192.000000     10.200000
# max     540.000000   359.400000   200.100000   247.000000     32.200000
#
#          coarseagg      fineagg          age     strength
# count  1030.000000  1030.000000  1030.000000  1030.000000
# mean    972.918932   773.580485    45.662136    35.817961
# std      77.753954    80.175980    63.169912    16.705742
# min     801.000000   594.000000     1.000000     2.330000
# ...

# %%
df.columns
# Out:
# Index(['cement', 'slag', 'ash', 'water', 'superplastic', 'coarseagg',
#        'fineagg', 'age', 'strength'],
#       dtype='object')

# %%
#le prime 8 colonne sono features, l'8^, cioè strength, è il target
#non serve encoding (è già tutto numero), ma sicuramente devo fare dei passaggi di feature scaling

# %%
# scikit-learn variables engineering
from sklearn.preprocessing import MinMaxScaler, StandardScaler

# %% [markdown]
# # STANDARDIZZAZIONE
#
# ## Su tutte le features

# %%
X = df.drop(["strength"], axis = 1).values #features
y = df.strength #label

# standardizzazione di tutto il df
st_scaler = StandardScaler().fit(X)

# transform training data
X_std = st_scaler.transform(X)

df_std = pd.DataFrame(X_std, columns=['cement', 'slag', 'ash', 'water', 'superplastic', 'coarseagg',
       'fineagg', 'age'])

df_std
# Out:
#         cement      slag       ash     water  superplastic  coarseagg  \
# 0     2.477915 -0.856888 -0.847144 -0.916764     -0.620448   0.863154
# 1     2.477915 -0.856888 -0.847144 -0.916764     -0.620448   1.056164
# 2     0.491425  0.795526 -0.847144  2.175461     -1.039143  -0.526517
# 3     0.491425  0.795526 -0.847144  2.175461     -1.039143  -0.526517
# 4    -0.790459  0.678408 -0.847144  0.488793     -1.039143   0.070527
# ...        ...       ...       ...       ...           ...        ...
# 1025 -0.045645  0.488235  0.564545 -0.092171      0.451410  -1.323005
# 1026  0.392819 -0.856888  0.960068  0.676200      0.702626  -1.994680
# 1027 -1.270088  0.759579  0.850635  0.521589     -0.017528  -1.036064
# 1028 -1.168610  1.308065 -0.847144 -0.279579      0.853356   0.214641
# 1029 -0.194033  0.308499  0.376945  0.891719      0.401166  -1.395062
#
#        fineagg       age
# 0    -1.217670 -0.279733
# 1    -1.217670 -0.279733
# 2    -2.240917  3.553066
# ...

# %%
feat_cols = ['cement', 'slag', 'ash', 'water', 'superplastic', 'coarseagg',
       'fineagg', 'age']

#plot unscaled
plt.figure(figsize=(20,15))
sns.boxplot(data=df[feat_cols]);

# %%
#plot standardized
plt.figure(figsize=(20,15))
sns.boxplot(data=df_std[feat_cols]);

# %%
df_std.describe()
# Out:
#              cement          slag           ash         water  superplastic  \
# count  1.030000e+03  1.030000e+03  1.030000e+03  1.030000e+03  1.030000e+03
# mean  -3.862875e-16  8.057740e-16  9.156645e-17  1.746176e-17 -3.951532e-16
# std    1.000486e+00  1.000486e+00  1.000486e+00  1.000486e+00  1.000486e+00
# min   -1.715253e+00 -8.568879e-01 -8.471439e-01 -2.800211e+00 -1.039143e+00
# 25%   -8.500535e-01 -8.568879e-01 -8.471439e-01 -7.808939e-01 -1.039143e+00
# 50%   -7.915193e-02 -6.017783e-01 -8.471439e-01  1.608294e-01  3.271508e-02
# 75%    6.589606e-01  8.007446e-01  1.002278e+00  4.887927e-01  6.691307e-01
# max    2.477915e+00  3.310675e+00  2.281084e+00  3.065647e+00  4.353642e+00
#
#           coarseagg       fineagg           age
# count  1.030000e+03  1.030000e+03  1.030000e+03
# mean   7.295135e-16 -2.917030e-16  1.534910e-16
# std    1.000486e+00  1.000486e+00  1.000486e+00
# min   -2.212138e+00 -2.240917e+00 -7.073594e-01
# ...

# %% [markdown]
# # NORMALIZZAZIONE
#
# ## Su tutte le features

# %%
# normalizzazione di tutto il df
nor_scaler = MinMaxScaler().fit(X)

# transform training data
X_nor = nor_scaler.transform(X)

df_nor = pd.DataFrame(X_nor, columns=['cement', 'slag', 'ash', 'water', 'superplastic', 'coarseagg',
       'fineagg', 'age'])

df_nor
# Out:
#         cement      slag       ash     water  superplastic  coarseagg  \
# 0     1.000000  0.000000  0.000000  0.321086      0.077640   0.694767
# 1     1.000000  0.000000  0.000000  0.321086      0.077640   0.738372
# 2     0.526256  0.396494  0.000000  0.848243      0.000000   0.380814
# 3     0.526256  0.396494  0.000000  0.848243      0.000000   0.380814
# 4     0.220548  0.368392  0.000000  0.560703      0.000000   0.515698
# ...        ...       ...       ...       ...           ...        ...
# 1025  0.398174  0.322760  0.451274  0.461661      0.276398   0.200872
# 1026  0.502740  0.000000  0.577711  0.592652      0.322981   0.049128
# 1027  0.106164  0.387869  0.542729  0.566294      0.189441   0.265698
# 1028  0.130365  0.519477  0.000000  0.429712      0.350932   0.548256
# 1029  0.362785  0.279633  0.391304  0.629393      0.267081   0.184593
#
#        fineagg       age
# 0     0.205720  0.074176
# 1     0.205720  0.074176
# 2     0.000000  0.739011
# ...

# %%
#plot normalized
plt.figure(figsize=(20,15))
sns.boxplot(data=df_nor[feat_cols]);

# %% [markdown]
# # CON DIVERSE SCALE
# ## visto che alcune features hanno una distribuzione gaussiana, altre no...

# %%
#standardizzo features che mostrano distribuzione gaussiana
#normalizzo le altre
#con column transformer o make column transformer

from sklearn.compose import ColumnTransformer, make_column_transformer

# %%
mct = make_column_transformer(
    (MinMaxScaler(), ["age", "ash", "slag","superplastic"]),
    (StandardScaler(), ["cement", "water", "coarseagg", "fineagg"])
)

X_mct = mct.fit_transform(df)

df_mct = pd.DataFrame(X_mct, columns=['cement_st', 'slag_mm', 'ash_mm', 'water_st', 'superplastic_mm', 'coarseagg_st',
       'fineagg_st', 'age_mm'])

df_mct
# Out:
#       cement_st   slag_mm    ash_mm  water_st  superplastic_mm  coarseagg_st  \
# 0      0.074176  0.000000  0.000000  0.077640         2.477915     -0.916764
# 1      0.074176  0.000000  0.000000  0.077640         2.477915     -0.916764
# 2      0.739011  0.000000  0.396494  0.000000         0.491425      2.175461
# 3      1.000000  0.000000  0.396494  0.000000         0.491425      2.175461
# 4      0.986264  0.000000  0.368392  0.000000        -0.790459      0.488793
# ...         ...       ...       ...       ...              ...           ...
# 1025   0.074176  0.451274  0.322760  0.276398        -0.045645     -0.092171
# 1026   0.074176  0.577711  0.000000  0.322981         0.392819      0.676200
# 1027   0.074176  0.542729  0.387869  0.189441        -1.270088      0.521589
# 1028   0.074176  0.000000  0.519477  0.350932        -1.168610     -0.279579
# 1029   0.074176  0.391304  0.279633  0.267081        -0.194033      0.891719
#
#       fineagg_st    age_mm
# ...

# %%
#plot tranformed

tr_cols= ['cement_st', 'slag_mm', 'ash_mm', 'water_st', 'superplastic_mm',
       'coarseagg_st', 'fineagg_st', 'age_mm']

plt.figure(figsize=(20,15))
sns.boxplot(data=df_mct[tr_cols]);

# %% [markdown]
# # KNN - STANDARDIZZAZIONE
#
# ## Isolando campione di test per verificare accuratezza modello

# %%
from sklearn.model_selection import train_test_split
from sklearn.neighbors import KNeighborsRegressor #regressor perchè non ho classi ma un valore, la forza, da calcolare
#r2 score
from sklearn.metrics import r2_score

# %%
Xs = df.drop(["strength"], axis = 1) #features
ys = df[["strength"]] #label

#ho già definito prima X e Y

X_train_s, X_test_s, y_train_s, y_test_s = train_test_split(Xs, ys, test_size=0.1, random_state=42) #voglio 10% df di test


#st_scaler = StandardScaler().fit(X)

X_train_prep_st = st_scaler.fit_transform(X_train_s) #df di training con fit e transform
X_test_prep_st = st_scaler.transform(X_test_s) # df di test solo transform

# %%
#definisco algoritmo KNN

knn_std = KNeighborsRegressor(n_neighbors=5)

knn_std.fit(X_train_prep_st, y_train_s.values.reshape(-1,))  #reshape (-1) per trasformare vettore riga in colonna e viceversa
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /var/folders/h7/cn1mtty524s4zrtrwdx93zp00000gn/T/ipykernel_1769/3934368741.py in <module>
#       1 #definisco algoritmo KNN
#       2
# ----> 3 knn_std = KNeighborsRegressor(n_neighbors=5)
#       4
#       5 knn_std.fit(X_train_prep_st, y_train_s.values.reshape(-1,))  #reshape (-1) per trasformare vettore riga in colonna e viceversa
#
# NameError: name 'KNeighborsRegressor' is not defined

# %%
#controllo l'accuratezza delle previsioni

y_pred_s = knn_std.predict(X_test_prep_st)
r2_score(y_test_s, y_pred_s)
# Out:
# 0.7324337717055658

# %%
knn_std.score(X_test_prep_st,y_test_s)
# Out:
# 0.7324337717055658

# %% [markdown]
# # KNN - NORMALIZZAZIONE
# ## Isolando campione di test per verificare accuratezza modello

# %%
Xn = df.drop(["strength"], axis = 1) #features
yn = df[["strength"]] #label


X_train_n, X_test_n, y_train_n, y_test_n = train_test_split(Xn, yn, test_size=0.1, random_state=42) #voglio 10% df di test

#nor_scaler = MinMaxScaler().fit(X)

X_train_prep_nor = nor_scaler.fit_transform(X_train_n) #df di training con fit e transform
X_test_prep_nor = nor_scaler.transform(X_test_n) # df di test solo transform

# %%
#applico KNN regressor

knn_norm = KNeighborsRegressor(n_neighbors=5)
knn_norm.fit(X_train_prep_nor, y_train_n.values.reshape(-1,))  #reshape (-1) per trasformare vettore riga in colonna e viceversa
# Out:
# KNeighborsRegressor()

# %%
#controllo l'accuratezza delle previsioni

y_pred_n = knn_norm.predict(X_test_prep_nor)
r2_score(y_test_n, y_pred_n)
# Out:
# 0.7029753289202155

# %%
knn_norm.score(X_test_prep_nor,y_test)
# Out:
# 0.7029753289202155

# %% [markdown]
# # KNN - BASELINE
# ## Isolando campione di test per verificare accuratezza modello

# %%
Xb = df.drop(["strength"], axis = 1) #features
yb = df[["strength"]] #label

X_train_b, X_test_b, y_train_b, y_test_b = train_test_split(Xb, yb, test_size=0.1, random_state=42) #voglio 10% df di test


#applico KNN regressor

knn_base = KNeighborsRegressor(n_neighbors=5)
knn_base.fit(X_train_b, y_train_b.values.reshape(-1,))  #reshape (-1) per trasformare vettore riga in colonna e viceversa

knn_base.fit(X_train_b, y_train_b.values.reshape(-1,))  #reshape (-1) per trasformare vettore riga in colonna e viceversa

y_pred_b = knn.predict(X_test_b)

r2_score(y_test_b, y_pred_b)
# Out:
# 0.755158952677822

# %%
knn_base.score(X_test_b,y_test_b)
# Out:
# 0.755158952677822

# %%
#cerco di capire il numero di vicini migliore --> BEST N SONO TRA 4 E 6

for n in range(3,21):
    knn_loop = KNeighborsRegressor(n_neighbors=n)
    knn_loop.fit(X_train_b, y_train.values.reshape(-1,))
    print(n, knn_loop.score(X_test_b,y_test))
# Out:
# 3 0.7285295509289926
# 4 0.7548410815512094
# 5 0.755158952677822
# 6 0.7596285225811004
# 7 0.7333873833165849
# 8 0.7293202518108706
# 9 0.7194350538461145
# 10 0.6907499264906136
# 11 0.6707033865753995
# 12 0.665794291877676
# 13 0.6535288879563259
# 14 0.6581702209824939
# 15 0.6568829401799607
# 16 0.6581685224274637
# 17 0.6599453567256202
# 18 0.6484699190374299
# 19 0.6243617649815695
# 20 0.6153001502357623

# %% [markdown]
# # KNN - TRANSFORMED [FAIL]  😒
# ## Isolando campione di test per verificare accuratezza modello

# %%
#tentativo 1 


#mct = make_column_transformer(
#    (MinMaxScaler(), ["age", "ash", "slag","superplastic"]),
#    (StandardScaler(), ["cement", "water", "coarseagg", "fineagg"])
#)

df_train_mct=df[0:900]

df_test_mct=df[900:]

Xtrain = df_train_mct.drop(["strength"], axis = 1) #features
ytrain = df_train_mct[["strength"]] #label

Xtest = df_test_mct.drop(["strength"], axis = 1) #features
ytest = df_test_mct[["strength"]] #label

X_train_prep_mct = mct.fit_transform(Xtrain) #df di training con fit e transform
X_test_prep_mct = mct.transform(Xtest) # df di test solo transform


knn_mct = KNeighborsRegressor(n_neighbors=5)
knn_mct.fit(X_train_prep_mct, ytrain)  #reshape (-1) per trasformare vettore riga in colonna e viceversa


y_pred_mct = knn.predict(X_test_prep_mct)

r2_score(ytest, y_pred_mct)
# Out:
# -0.00030865858445716654

# %%
#tentativo 2

Xt = df.drop(["strength"], axis = 1) #features
yt = df[["strength"]] #label

X_train_t, X_test_t, y_train_t, y_test_t = train_test_split(Xt, yt, test_size=0.1, random_state=42) #voglio 10% df di test

X_train_prep_trf = mct.fit_transform(X_train_t) #df di training con fit e transform
X_test_prep_trf = mct.transform(X_test_t) # df di test solo transform

#applico KNN regressor

knn_trf = KNeighborsRegressor(n_neighbors=5)
knn_trf.fit(X_train_prep_trf, y_train_t)  #reshape (-1) per trasformare vettore riga in colonna e viceversa


y_pred_trf = knn.predict(X_test_prep_trf)

r2_score(y_test_t, y_pred_trf)
# Out:
# -0.02595552376904542

# %%
knn_trf.score(X_test_t,y_test_t)
# Out:
# -0.6652265822037347

# %% [markdown]
# # CONFRONTO ACCURATEZZA MODELLI

# %%
print("Features normalizzate: ",knn_norm.score(X_test_prep_nor,y_test), " \U0001F949	")
print("Features standardizzate: ",knn_std.score(X_test_prep_st,y_test_s), " \U0001F948	")
print("Features trasformate: ",knn_trf.score(X_test_t,y_test_t)," <-- sicuramente c'è un errore nel codice \U0001F605")
print("Features base: ",knn_base.score(X_test_b,y_test_b)," \U0001F3C6	")
# Out:
# Features normalizzate:  0.7029753289202155  🥉
# Features standardizzate:  0.7324337717055658  🥈
# Features trasformate:  -0.6652265822037347  <-- sicuramente c'è un errore nel codice 😅
# Features base:  0.755158952677822  🏆

# %% [markdown]
# # GRAFICI 🐱‍🏍

# %%
df.corr() # --> solo per iniziare a vedere le correlazioni
# Out:
#                 cement      slag       ash     water  superplastic  coarseagg  \
# cement        1.000000 -0.275216 -0.397467 -0.081587      0.092386  -0.109349
# slag         -0.275216  1.000000 -0.323580  0.107252      0.043270  -0.283999
# ash          -0.397467 -0.323580  1.000000 -0.256984      0.377503  -0.009961
# water        -0.081587  0.107252 -0.256984  1.000000     -0.657533  -0.182294
# superplastic  0.092386  0.043270  0.377503 -0.657533      1.000000  -0.265999
# coarseagg    -0.109349 -0.283999 -0.009961 -0.182294     -0.265999   1.000000
# fineagg      -0.222718 -0.281603  0.079108 -0.450661      0.222691  -0.178481
# age           0.081946 -0.044246 -0.154371  0.277618     -0.192700  -0.003016
# strength      0.497832  0.134829 -0.105755 -0.289633      0.366079  -0.164935
#
#                fineagg       age  strength
# cement       -0.222718  0.081946  0.497832
# slag         -0.281603 -0.044246  0.134829
# ash           0.079108 -0.154371 -0.105755
# ...

# %%
#heatmap delle correlazioni --> non è merito mio, ho preso spunto :P

sns.heatmap(df.corr(), annot=True,cmap='coolwarm')
# Out:
# <AxesSubplot:>

# %%
#presenza di cemento vs forza

df.plot(kind='scatter', x='cement', y='strength', 
    title = "Is cement determining concrete's strength?", figsize=(20,13), color='violet');

# %%
#compresenza di cenere e superplastiche

df.plot(kind='scatter', x='ash', y='superplastic', 
    title = "Is the presence of ash in cement related to the presence of superplastic?", figsize=(20,13), color='red');

# %%
#pairgrid

g = sns.PairGrid(df, height=4)
g.map_upper(sns.histplot)
g.map_lower(sns.kdeplot, fill=True)
g.map_diag(sns.histplot, kde=True);

# %%
#grana grossa e grana fine per età del cemento

fig = plt.figure(figsize=(25, 10))
fig.subplots_adjust(wspace=0.3)

ax1 = fig.add_subplot(121)
ax2 = fig.add_subplot(122)

x = df_std[["coarseagg", "fineagg"]].values
y = df_std[['age']].values

# Scatter plots:
ax1.scatter(x[:,0], y, marker='x', c='r', alpha=0.5, s=20, label='Grana grossa')
ax1.set_xlabel('Grana grossa')
ax1.set_ylabel('Età')
ax1.set_xlim(0, 3) #scala modificata in base alla standardizzazione

ax3 = ax1.twiny()
ax3.scatter(x[:,1], y, marker='o', c='b', alpha=0.4, s=20, label='Grana fine')
ax3.set_xlabel('Grana fine')
ax3.set_xlim(0, 3) #scala modificata in base alla standardizzazione

# Histograms:
ax2.hist(x[:,0], alpha=0.4, edgecolor='b', linewidth=0.8, label='Grana grossa')
ax2.set_xlabel('Grana grossa')
ax2.set_ylabel('Età')
ax2.set_xlim(0, 3) #scala modificata in base alla standardizzazione

ax4 = ax2.twiny()
ax4.hist(x[:,1], alpha=0.4, color='r', edgecolor='r', linewidth=0.8, label='Grana fine')
ax4.set_xlabel('Grana fine')
ax4.set_xlim(0, 3); #scala modificata in base alla standardizzazione

# %%
#per capire quali feature hanno distribuzione gaussiana
#non è merito mio, ho preso spunto perchè è una rappresentazione bellissima *W*


fig,axes = plt.subplots(3,3, constrained_layout=True)

for i,ax in enumerate(axes.ravel()):
    colore = np.random.rand(3,)
    graph= sns.histplot(x = df.iloc[:,i], kde=True,color=[colore],ax=ax)
